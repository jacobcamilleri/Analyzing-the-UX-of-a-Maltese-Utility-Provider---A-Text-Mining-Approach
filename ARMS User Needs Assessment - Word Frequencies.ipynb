# %%
import pandas as pd
import numpy as np
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk import ngrams
from collections import Counter

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # PPT01

# %%
PPT01 = pd.read_excel('PPT01.xlsx')
PPT01 = PPT01.loc[PPT01['Person'] == 'Interviewer']

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/Owner/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Owner/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
answers = " ".join(PPT01['Question/Answer'])
words = word_tokenize(answers)

# %%
def clean_words(new_tokens):
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens = [t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens = [lemmatizer.lemmatize(t) for t in new_tokens]
    return new_tokens

# %%
lowered = clean_words(words)

# %%
bow = Counter(lowered)

# %%
data = pd.DataFrame(bow.items(), columns=['word', 'frequency']).sort_values(by='frequency', ascending=False)

# %%
data = data.head(20)

# %%
sns.barplot(x='frequency',y='word',data=data)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
bow2 = Counter(ngrams(lowered,2))
#bow2

# %%
def word_frequency(sentence):
    sentence =" ".join(sentence)
    new_tokens = word_tokenize(sentence)
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    counted = Counter(new_tokens)
    counted_2= Counter(ngrams(new_tokens,2))
    counted_3= Counter(ngrams(new_tokens,3))
    word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
    word_pairs =pd.DataFrame(counted_2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
    trigrams =pd.DataFrame(counted_3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
    return word_freq,word_pairs,trigrams

# %%
data2,data3,data4 = word_frequency(Keith['Question/Answer'])

# %%
data2
# Out:
#              word  frequency
# 16        service         15
# 0             pay          9
# 172       website          8
# 34            one          8
# 22       customer          8
# ..            ...        ...
# 149  misconstrued          1
# 48      explained          1
# 151          area          1
# 47       properly          1
# 251        option          1
#
# [252 rows x 2 columns]

# %%
data3
# Out:
#                    pairs  frequency
# 66      (customer, care)          4
# 209      (utility, bill)          3
# 381        (mobile, app)          2
# 51          (via, email)          2
# 37            (end, day)          2
# ..                   ...        ...
# 154   (applied, service)          1
# 153   (payment, applied)          1
# 152  (received, payment)          1
# 151  (whether, received)          1
# 454          (kind, use)          1
#
# [455 rows x 2 columns]

# %%
data4
# Out:
#                           trigrams  frequency
# 298     (customer, care, function)          2
# 98           (better, print, form)          2
# 164  (receive, form, confirmation)          2
# 313      (help, instantly, people)          1
# 324          (take, long, example)          1
# ..                             ...        ...
# 154            (form, update, end)          1
# 153         (asking, form, update)          1
# 152          (email, asking, form)          1
# 151          (send, email, asking)          1
# 472            (online, kind, use)          1
#
# [473 rows x 2 columns]

# %%
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=data2.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=data3.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=data4.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='trigrams'>

# %% [markdown]
# # PPT02

# %%
PPT02 = pd.read_excel('PPT02.xlsx')
PPT02 = PPT02.loc[PPT02['Person'] == 'Interviewer']

# %%
answers = " ".join(PPT02['Question/Answer'])
words = word_tokenize(answers)

# %%
def clean_words(new_tokens):
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens = [t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens = [lemmatizer.lemmatize(t) for t in new_tokens]
    return new_tokens

# %%
lowered = clean_words(words)

# %%
bow = Counter(lowered)

# %%
data = pd.DataFrame(bow.items(), columns=['word', 'frequency']).sort_values(by='frequency', ascending=False)

# %%
data = data.head(20)

# %%
sns.barplot(x='frequency',y='word',data=data)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
bow2 = Counter(ngrams(lowered,2))
#bow2

# %%
def word_frequency(sentence):
    sentence =" ".join(sentence)
    new_tokens = word_tokenize(sentence)
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    counted = Counter(new_tokens)
    counted_2= Counter(ngrams(new_tokens,2))
    counted_3= Counter(ngrams(new_tokens,3))
    word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
    word_pairs =pd.DataFrame(counted_2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
    trigrams =pd.DataFrame(counted_3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
    return word_freq,word_pairs,trigrams

# %%
data2,data3,data4 = word_frequency(Ven['Question/Answer'])

# %%
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=data2.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=data3.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=data4.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='trigrams'>

# %% [markdown]
# # All

# %%
All = pd.read_excel('ARMS User Needs Assessment.xlsx')
All = All.loc[All['Person'] != 'Interviewer']

# %%
answers = " ".join(All['Question/Answer'])
words = word_tokenize(answers)

# %%
def clean_words(new_tokens):
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens = [t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens = [lemmatizer.lemmatize(t) for t in new_tokens]
    return new_tokens

# %%
lowered = clean_words(words)

# %%
bow = Counter(lowered)

# %%
data = pd.DataFrame(bow.items(), columns=['word', 'frequency']).sort_values(by='frequency', ascending=False)

# %%
data = data.head(20)

# %%
data
# Out:
#          word  frequency
# 16    service         30
# 78       form         20
# 22   customer         15
# 137      bill         14
# 64        yes         13
# 172   website         12
# 168     would         12
# 0         pay         11
# 117     think         11
# 173  actually         10
# 14    payment          9
# 242      yeah          9
# 34        one          9
# 246     could          9
# 27       took          9
# 166      mean          9
# 163    online          8
# 61        get          8
# 83     really          8
# 65       time          8

# %%
sns.barplot(x='frequency',y='word',data=data)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
bow2 = Counter(ngrams(lowered,2))
#bow2

# %%
def word_frequency(sentence):
    sentence =" ".join(sentence)
    new_tokens = word_tokenize(sentence)
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    counted = Counter(new_tokens)
    counted_2= Counter(ngrams(new_tokens,2))
    counted_3= Counter(ngrams(new_tokens,3))
    word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
    word_pairs =pd.DataFrame(counted_2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
    trigrams =pd.DataFrame(counted_3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
    return word_freq,word_pairs,trigrams

# %%
data2,data3,data4 = word_frequency(All['Question/Answer'])

# %%
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=data2.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=data3.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=data4.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='trigrams'>
